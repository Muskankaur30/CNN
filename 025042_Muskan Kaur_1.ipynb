# %%
# We install the FER() library to perform facial recognition
# This installation will also take care of any of the above dependencies if they are missing

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
from keras.utils.np_utils import to_categorical
import os.path

# %%
from fer import FER
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
test_image_one = plt.imread("C:/Users/muska/Downloads/OneDrive_2022-08-10/Practice set 1/Image-One.jpeg")
emo_detector = FER(mtcnn=True)
# Capture all the emotions on the image
captured_emotions = emo_detector.detect_emotions(test_image_one)
# Print all captured emotions with the image
print(captured_emotions)
plt.imshow(test_image_one)
# Out:
# ...
# 1/1 [==============================] - 0s 199ms/step
# [{'box': [133, 47, 214, 293], 'emotions': {'angry': 0.01, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.01, 'sad': 0.01, 'surprise': 0.0, 'neutral': 0.97}}]

# %%
# Use the top Emotion() function to call for the dominant emotion in the image
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_one)
print(dominant_emotion, emotion_score)
# Out:
# ...
# 1/1 [==============================] - 0s 26ms/step
# neutral 0.97

# %%
# We repeat the same steps for a few other images to confirm the performance of FER()
test_image_two = plt.imread("C:/Users/muska/Downloads/OneDrive_2022-08-10/Practice set 1/Image-Two.jpg")
captured_emotions_two = emo_detector.detect_emotions(test_image_two)
print(captured_emotions_two)
plt.imshow(test_image_two)
dominant_emotion_two, emotion_score_two = emo_detector.top_emotion(test_image_two)
print(dominant_emotion_two, emotion_score_two)
# Out:
# ...
# 1/1 [==============================] - 0s 35ms/step
# [{'box': [46, 48, 78, 110], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.98, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.01}}]
# ...
# 1/1 [==============================] - 0s 34ms/step
# happy 0.98

# %%
# Testing on another image
test_image_three = plt.imread("C:/Users/muska/Downloads/OneDrive_2022-08-10/Practice set 1/Image-Three.jpg")
captured_emotions_three = emo_detector.detect_emotions(test_image_three)
print(captured_emotions_three)
plt.imshow(test_image_three)
dominant_emotion_three, emotion_score_three = emo_detector.top_emotion(test_image_three)
print(dominant_emotion_three, emotion_score_three)
# Out:
# ...
# 1/1 [==============================] - 0s 28ms/step
# [{'box': [261, 193, 463, 676], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.58, 'sad': 0.02, 'surprise': 0.0, 'neutral': 0.4}}]
# ...
# 1/1 [==============================] - 0s 25ms/step
# happy 0.58

# %%
# Testing on another image
test_image_four = plt.imread("C:/Users/muska/Downloads/OneDrive_2022-08-10/Practice set 1/Image-Four.jpg")
captured_emotions_four = emo_detector.detect_emotions(test_image_four)
print(captured_emotions_four)
plt.imshow(test_image_four)
dominant_emotion_four, emotion_score_four = emo_detector.top_emotion(test_image_four)
print(dominant_emotion_four, emotion_score_four)
# Out:
# ...
# 1/1 [==============================] - 0s 30ms/step
# [{'box': [169, 75, 199, 237], 'emotions': {'angry': 0.78, 'disgust': 0.0, 'fear': 0.14, 'happy': 0.0, 'sad': 0.03, 'surprise': 0.01, 'neutral': 0.04}}]
# ...
# 1/1 [==============================] - 0s 32ms/step
# angry 0.78

# %%
# Testing on another image
test_image_five = plt.imread("C:/Users/muska/Downloads/Image_Five.jpg")
captured_emotions_five = emo_detector.detect_emotions(test_image_five)
print(captured_emotions_five)
plt.imshow(test_image_five)
dominant_emotion_five, emotion_score_five = emo_detector.top_emotion(test_image_five)
print(dominant_emotion_five, emotion_score_five)
# Out:
# ...
# 1/1 [==============================] - 0s 26ms/step
# [{'box': [144, 105, 267, 375], 'emotions': {'angry': 0.24, 'disgust': 0.0, 'fear': 0.02, 'happy': 0.16, 'sad': 0.02, 'surprise': 0.02, 'neutral': 0.53}}]
# ...
# 1/1 [==============================] - 0s 26ms/step
# neutral 0.53

# %%
# Testing on another image
test_image_six = plt.imread("C:/Users/muska/Downloads/Image_Six.jpg")
captured_emotions_six = emo_detector.detect_emotions(test_image_six)
print(captured_emotions_six)
plt.imshow(test_image_six)
dominant_emotion_six, emotion_score_six = emo_detector.top_emotion(test_image_six)
print(dominant_emotion_six, emotion_score_six)
# Out:
# ...
# 1/1 [==============================] - 0s 20ms/step
# [{'box': [42, 47, 111, 159], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 1.0, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.0}}]
# ...
# 1/1 [==============================] - 0s 25ms/step
# happy 1.0

# %%
# Testing on another image
test_image_seven = plt.imread("C:/Users/muska/Downloads/Image_Seven.jpg")
captured_emotions_seven = emo_detector.detect_emotions(test_image_seven)
print(captured_emotions_seven)
plt.imshow(test_image_seven)
dominant_emotion_seven, emotion_score_seven = emo_detector.top_emotion(test_image_seven)
print(dominant_emotion_seven, emotion_score_seven)
# Out:
# ...
# 1/1 [==============================] - 0s 24ms/step
# [{'box': [116, 37, 68, 89], 'emotions': {'angry': 0.12, 'disgust': 0.0, 'fear': 0.81, 'happy': 0.0, 'sad': 0.0, 'surprise': 0.07, 'neutral': 0.0}}]
# ...
# 1/1 [==============================] - 0s 24ms/step
# fear 0.81
